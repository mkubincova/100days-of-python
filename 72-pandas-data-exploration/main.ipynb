# %%
import pandas as pd
df = pd.read_csv('salaries_by_college_major.csv')

df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# 12                False                   False                     False
# 13                False                   False                     False
# 14                False                   False                     False
# 15                False                   False                     False
# 16                False                   False                     False
# 17                False                   False                     False
# 18                False                   False                     False
# 19                False                   False                     False
# 20                False                   False                     False
# 21                False                   False                     False
# 22                False                   False                     False
# 23                False                   False                     False
# 24                False                   False                     False
# 25                False                   False                     False
# 26                False                   False                     False
# 27                False                   False                     False
# 28                False                   False                     False
# 29                False                   False                     False
# 30                False                   False                     False
# 31                False                   False                     False
# 32                False                   False                     False
# 33                False                   False                     False
# 34                False                   False                     False
# 35                False                   False                     False
# 36                False                   False                     False
# 37                False                   False                     False
# 38                False                   False                     False
# 39                False                   False                     False
# 40                False                   False                     False
# 41                False                   False                     False
# 42                False                   False                     False
# 43                False                   False                     False
# 44                False                   False                     False
# 45                False                   False                     False
# 46                False                   False                     False
# 47                False                   False                     False
# 48                False                   False                     False
# 49                False                   False                     False
# 50                False                    True                      True
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                               False                              False
# 1                               False                              False
# 2                               False                              False
# 3                               False                              False
# 4                               False                              False
# 5                               False                              False
# 6                               False                              False
# 7                               False                              False
# 8                               False                              False
# 9                               False                              False
# 10                              False                              False
# 11                              False                              False
# 12                              False                              False
# 13                              False                              False
# 14                              False                              False
# 15                              False                              False
# 16                              False                              False
# 17                              False                              False
# 18                              False                              False
# 19                              False                              False
# 20                              False                              False
# 21                              False                              False
# 22                              False                              False
# 23                              False                              False
# 24                              False                              False
# 25                              False                              False
# 26                              False                              False
# 27                              False                              False
# 28                              False                              False
# 29                              False                              False
# 30                              False                              False
# 31                              False                              False
# 32                              False                              False
# 33                              False                              False
# 34                              False                              False
# 35                              False                              False
# 36                              False                              False
# 37                              False                              False
# 38                              False                              False
# 39                              False                              False
# 40                              False                              False
# 41                              False                              False
# 42                              False                              False
# 43                              False                              False
# 44                              False                              False
# 45                              False                              False
# 46                              False                              False
# 47                              False                              False
# 48                              False                              False
# 49                              False                              False
# 50                               True                               True
#
#     Group
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
# 40  False
# 41  False
# 42  False
# 43  False
# 44  False
# 45  False
# 46  False
# 47  False
# 48  False
# 49  False
# 50   True

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
lean_df['Starting Median Salary'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8d9e5fe79258> in <cell line: 1>()
# ----> 1 lean_df['Starting Median Salary'].max()
#
# NameError: name 'lean_df' is not defined

# %%
clean_df['Starting Median Salary'].max()
# Out:
# 74300.0

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_df['Mid-Career Median Salary'].idxmax()
# Out:
# 8

# %%
clean_df['Undergraduate Major'][8]
# Out:
# 'Chemical Engineering'

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, 'Spread', spread_col)
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# 3                           138000.0      HASS
# 4                           136000.0  Business

# %%
low_risk = clean_df.sort_values('Spread')
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
high_potential = clean_df.sort_values('Mid-Career 90th Percentile Salary')
high_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].tail()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 44               Physics                           178000.0
# 37                  Math                           183000.0
# 8   Chemical Engineering                           194000.0
# 22               Finance                           195000.0
# 17             Economics                           210000.0

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Spread  Starting Median Salary  \
# Group
# Business                   12      12                      12
# HASS                       22      22                      22
# STEM                       16      16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16

# %%
clean_df.groupby('Group').mean()
# Out:
# <ipython-input-22-61aa9b47bd8a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby('Group').mean()
#                  Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business  103958.333333            44633.333333              75083.333333
# HASS       95218.181818            37186.363636              62968.181818
# STEM      101600.000000            53862.500000              90812.500000
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                       43566.666667                      147525.000000
# HASS                           34145.454545                      129363.636364
# STEM                           56025.000000                      157625.000000

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
clean_df.groupby('Group').mean()
# Out:
# <ipython-input-24-61aa9b47bd8a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_df.groupby('Group').mean()
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00

# %%
table_from_html = pd.read_html("https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors")
df = table_from_html[0].copy()
df.columns = ["Rank", "Major", "Type", "EarlyCareerPay", "MidCareerPay", "HighMeaning"]

# %%
df.head()
# Out:
#      Rank                                              Major  \
# 0  Rank:1                        Major:Petroleum Engineering
# 1  Rank:2  Major:Operations Research & Industrial Enginee...
# 2  Rank:3                           Major:Interaction Design
# 3  Rank:4             Major:Applied Economics and Management
# 4  Rank:5                             Major:Building Science
#
#                     Type            EarlyCareerPay             MidCareerPay  \
# 0  Degree Type:Bachelors  Early Career Pay:$97,500  Mid-Career Pay:$212,500
# 1  Degree Type:Bachelors  Early Career Pay:$98,300  Mid-Career Pay:$191,800
# 2  Degree Type:Bachelors  Early Career Pay:$74,700  Mid-Career Pay:$173,600
# 3  Degree Type:Bachelors  Early Career Pay:$76,500  Mid-Career Pay:$164,400
# 4  Degree Type:Bachelors  Early Career Pay:$69,000  Mid-Career Pay:$163,100
#
#           HighMeaning
# 0  % High Meaning:61%
# 1  % High Meaning:21%
# 2  % High Meaning:54%
# 3  % High Meaning:54%
# 4  % High Meaning:47%

# %%
table_from_html = pd.read_html("https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors")
df = table_from_html[0].copy()
df.head()
# Out:
#      Rank                                              Major  \
# 0  Rank:1                        Major:Petroleum Engineering
# 1  Rank:2  Major:Operations Research & Industrial Enginee...
# 2  Rank:3                           Major:Interaction Design
# 3  Rank:4             Major:Applied Economics and Management
# 4  Rank:5                             Major:Building Science
#
#              Degree Type  \
# 0  Degree Type:Bachelors
# 1  Degree Type:Bachelors
# 2  Degree Type:Bachelors
# 3  Degree Type:Bachelors
# 4  Degree Type:Bachelors
#
#   Early Career Pay  .t12aabb1-6c45-44ee-b63e-a412d12748ec {  color: #fff;  background: #222;  border: 1px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-top {  margin-top: -10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-top::before {  border-top: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-top::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  bottom: -6px;  left: 50%;  margin-left: -8px;  border-top-color: #222;  border-top-style: solid;  border-top-width: 6px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-bottom {  margin-top: 10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-bottom::before {  border-bottom: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-bottom::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  top: -6px;  left: 50%;  margin-left: -8px;  border-bottom-color: #222;  border-bottom-style: solid;  border-bottom-width: 6px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-left {  margin-left: -10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-left::before {  border-left: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-left::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  right: -6px;  top: 50%;  margin-top: -4px;  border-left-color: #222;  border-left-style: solid;  border-left-width: 6px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-right {  margin-left: 10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-right::before {  border-right: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-right::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  left: -6px;  top: 50%;  margin-top: -4px;  border-right-color: #222;  border-right-style: solid;  border-right-width: 6px;  }  \
# 0                           Early Career Pay:$97,500
# 1                           Early Career Pay:$98,300
# 2                           Early Career Pay:$74,700
# 3                           Early Career Pay:$76,500
# 4                           Early Career Pay:$69,000
#
#   Mid-Career Pay  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4 {  color: #fff;  background: #222;  border: 1px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-top {  margin-top: -10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-top::before {  border-top: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-top::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  bottom: -6px;  left: 50%;  margin-left: -8px;  border-top-color: #222;  border-top-style: solid;  border-top-width: 6px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-bottom {  margin-top: 10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-bottom::before {  border-bottom: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-bottom::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  top: -6px;  left: 50%;  margin-left: -8px;  border-bottom-color: #222;  border-bottom-style: solid;  border-bottom-width: 6px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-left {  margin-left: -10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-left::before {  border-left: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-left::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  right: -6px;  top: 50%;  margin-top: -4px;  border-left-color: #222;  border-left-style: solid;  border-left-width: 6px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-right {  margin-left: 10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-right::before {  border-right: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-right::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  left: -6px;  top: 50%;  margin-top: -4px;  border-right-color: #222;  border-right-style: solid;  border-right-width: 6px;  }  \
# 0                            Mid-Career Pay:$212,500
# 1                            Mid-Career Pay:$191,800
# 2                            Mid-Career Pay:$173,600
# 3                            Mid-Career Pay:$164,400
# 4                            Mid-Career Pay:$163,100
#
#   % High Meaning  .t627e968-6bf8-451d-a640-45392c327b40 {  color: #fff;  background: #222;  border: 1px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-top {  margin-top: -10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-top::before {  border-top: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-top::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  bottom: -6px;  left: 50%;  margin-left: -8px;  border-top-color: #222;  border-top-style: solid;  border-top-width: 6px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-bottom {  margin-top: 10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-bottom::before {  border-bottom: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-bottom::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  top: -6px;  left: 50%;  margin-left: -8px;  border-bottom-color: #222;  border-bottom-style: solid;  border-bottom-width: 6px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-left {  margin-left: -10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-left::before {  border-left: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-left::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  right: -6px;  top: 50%;  margin-top: -4px;  border-left-color: #222;  border-left-style: solid;  border-left-width: 6px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-right {  margin-left: 10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-right::before {  border-right: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-right::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  left: -6px;  top: 50%;  margin-top: -4px;  border-right-color: #222;  border-right-style: solid;  border-right-width: 6px;  }
# 0                                 % High Meaning:61%
# 1                                 % High Meaning:21%
# 2                                 % High Meaning:54%
# 3                                 % High Meaning:54%
# 4                                 % High Meaning:47%

# %%
table_from_html = pd.read_html("https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors")
df = table_from_html[0].copy()
df.columns = ["Rank", "Major", "Type", "EarlyCareerPay", "MidCareerPay", "HighMeaning"]

# %%
for page_no in range(2, 35):
    table_from_html = pd.read_html(f"https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors/page/{page_no}")
    page_df = table_from_html[0].copy()
    page_df.columns = ["Rank", "Major", "Type", "EarlyCareerPay", "MidCareerPay", "HighMeaning"]
    df = df.append(page_df, ignore_index=True)
# Out:
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)
# <ipython-input-29-8210a5960ca6>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(page_df, ignore_index=True)

# %%
df.shape
# Out:
# (799, 6)

# %%
df = df[["Major", "EarlyCareerPay", "MidCareerPay"]]

# %%
df.head()
# Out:
#                                                Major  \
# 0                        Major:Petroleum Engineering
# 1  Major:Operations Research & Industrial Enginee...
# 2                           Major:Interaction Design
# 3             Major:Applied Economics and Management
# 4                             Major:Building Science
#
#              EarlyCareerPay             MidCareerPay
# 0  Early Career Pay:$97,500  Mid-Career Pay:$212,500
# 1  Early Career Pay:$98,300  Mid-Career Pay:$191,800
# 2  Early Career Pay:$74,700  Mid-Career Pay:$173,600
# 3  Early Career Pay:$76,500  Mid-Career Pay:$164,400
# 4  Early Career Pay:$69,000  Mid-Career Pay:$163,100

# %%
df.replace({"^Major:": "", "^Early Career Pay:\$": "", "^Mid-Career Pay:\$": "", ",": ""}, regex=True, inplace=True)
df.head()
# Out:
#                                           Major EarlyCareerPay MidCareerPay
# 0                         Petroleum Engineering          97500       212500
# 1  Operations Research & Industrial Engineering          98300       191800
# 2                            Interaction Design          74700       173600
# 3              Applied Economics and Management          76500       164400
# 4                              Building Science          69000       163100

# %%
df[["EarlyCareerPay", "MidCareerPay"]] = df[["EarlyCareerPay", "MidCareerPay"]].apply(pd.to_numeric)

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.head()
# Out:
#                                           Major  EarlyCareerPay  MidCareerPay
# 0                         Petroleum Engineering           97500        212500
# 1  Operations Research & Industrial Engineering           98300        191800
# 2                            Interaction Design           74700        173600
# 3              Applied Economics and Management           76500        164400
# 4                              Building Science           69000        163100

# %%
df.nlargest(6, 'EarlyCareerPay')
# Out:
#                                             Major  EarlyCareerPay  \
# 56                    Physician Assistant Studies          109600
# 1    Operations Research & Industrial Engineering           98300
# 0                           Petroleum Engineering           97500
# 117          Nuclear Engineering Technology (NET)           92500
# 6                             Operations Research           92200
# 60                      Metallurgical Engineering           90800
#
#      MidCareerPay
# 56         136500
# 1          191800
# 0          212500
# 117        122800
# 6          160000
# 60         135500

# %%
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list"

dfs = pd.read_html(url)

dfs
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
#  0                        Citizens Bank       Sac City      IA      8758
#  1             Heartland Tri-State Bank        Elkhart      KS     25851
#  2                  First Republic Bank  San Francisco      CA     59017
#  3                       Signature Bank       New York      NY     57053
#  4                  Silicon Valley Bank    Santa Clara      CA     24735
#  ..                                 ...            ...     ...       ...
#  563                 Superior Bank, FSB       Hinsdale      IL     32646
#  564                Malta National Bank          Malta      OH      6629
#  565    First Alliance Bank & Trust Co.     Manchester      NH     34264
#  566  National State Bank of Metropolis     Metropolis      IL      3815
#  567                   Bank of Honolulu       Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
#  0              Iowa Trust & Savings Bank    November 3, 2023     10545
#  1                 Dream First Bank, N.A.       July 28, 2023     10544
#  2              JPMorgan Chase Bank, N.A.         May 1, 2023     10543
#  3                    Flagstar Bank, N.A.      March 12, 2023     10540
#  4    First–Citizens Bank & Trust Company      March 10, 2023     10539
#  ..                                   ...                 ...       ...
#  563                Superior Federal, FSB       July 27, 2001      6004
#  564                    North Valley Bank         May 3, 2001      4648
#  565  Southern New Hampshire Bank & Trust    February 2, 2001      4647
#  566              Banterra Bank of Marion   December 14, 2000      4646
#  567                   Bank of the Orient    October 13, 2000      4645
#
#  [568 rows x 7 columns]]

# %%
dfs.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-e1bad85e32a7> in <cell line: 1>()
# ----> 1 dfs.tail()
#
# AttributeError: 'list' object has no attribute 'tail'

# %%
df = dfs[0]
df.tail()
# Out:
#                          Bank NameBank    CityCity StateSt  CertCert  \
# 563                 Superior Bank, FSB    Hinsdale      IL     32646
# 564                Malta National Bank       Malta      OH      6629
# 565    First Alliance Bank & Trust Co.  Manchester      NH     34264
# 566  National State Bank of Metropolis  Metropolis      IL      3815
# 567                   Bank of Honolulu    Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# 563                Superior Federal, FSB       July 27, 2001      6004
# 564                    North Valley Bank         May 3, 2001      4648
# 565  Southern New Hampshire Bank & Trust    February 2, 2001      4647
# 566              Banterra Bank of Marion   December 14, 2000      4646
# 567                   Bank of the Orient    October 13, 2000      4645

# %%
table_from_html = pd.read_html("https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors")
df = table_from_html[0]
df.head()
# Out:
#      Rank                                              Major  \
# 0  Rank:1                        Major:Petroleum Engineering
# 1  Rank:2  Major:Operations Research & Industrial Enginee...
# 2  Rank:3                           Major:Interaction Design
# 3  Rank:4             Major:Applied Economics and Management
# 4  Rank:5                             Major:Building Science
#
#              Degree Type  \
# 0  Degree Type:Bachelors
# 1  Degree Type:Bachelors
# 2  Degree Type:Bachelors
# 3  Degree Type:Bachelors
# 4  Degree Type:Bachelors
#
#   Early Career Pay  .t12aabb1-6c45-44ee-b63e-a412d12748ec {  color: #fff;  background: #222;  border: 1px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-top {  margin-top: -10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-top::before {  border-top: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-top::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  bottom: -6px;  left: 50%;  margin-left: -8px;  border-top-color: #222;  border-top-style: solid;  border-top-width: 6px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-bottom {  margin-top: 10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-bottom::before {  border-bottom: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-bottom::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  top: -6px;  left: 50%;  margin-left: -8px;  border-bottom-color: #222;  border-bottom-style: solid;  border-bottom-width: 6px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-left {  margin-left: -10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-left::before {  border-left: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-left::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  right: -6px;  top: 50%;  margin-top: -4px;  border-left-color: #222;  border-left-style: solid;  border-left-width: 6px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-right {  margin-left: 10px;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-right::before {  border-right: 8px solid transparent;  }  .t12aabb1-6c45-44ee-b63e-a412d12748ec.place-right::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  left: -6px;  top: 50%;  margin-top: -4px;  border-right-color: #222;  border-right-style: solid;  border-right-width: 6px;  }  \
# 0                           Early Career Pay:$97,500
# 1                           Early Career Pay:$98,300
# 2                           Early Career Pay:$74,700
# 3                           Early Career Pay:$76,500
# 4                           Early Career Pay:$69,000
#
#   Mid-Career Pay  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4 {  color: #fff;  background: #222;  border: 1px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-top {  margin-top: -10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-top::before {  border-top: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-top::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  bottom: -6px;  left: 50%;  margin-left: -8px;  border-top-color: #222;  border-top-style: solid;  border-top-width: 6px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-bottom {  margin-top: 10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-bottom::before {  border-bottom: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-bottom::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  top: -6px;  left: 50%;  margin-left: -8px;  border-bottom-color: #222;  border-bottom-style: solid;  border-bottom-width: 6px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-left {  margin-left: -10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-left::before {  border-left: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-left::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  right: -6px;  top: 50%;  margin-top: -4px;  border-left-color: #222;  border-left-style: solid;  border-left-width: 6px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-right {  margin-left: 10px;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-right::before {  border-right: 8px solid transparent;  }  .t19eaab3-0b81-4ff7-a9ec-fe61907a6bf4.place-right::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  left: -6px;  top: 50%;  margin-top: -4px;  border-right-color: #222;  border-right-style: solid;  border-right-width: 6px;  }  \
# 0                            Mid-Career Pay:$212,500
# 1                            Mid-Career Pay:$191,800
# 2                            Mid-Career Pay:$173,600
# 3                            Mid-Career Pay:$164,400
# 4                            Mid-Career Pay:$163,100
#
#   % High Meaning  .t627e968-6bf8-451d-a640-45392c327b40 {  color: #fff;  background: #222;  border: 1px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-top {  margin-top: -10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-top::before {  border-top: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-top::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  bottom: -6px;  left: 50%;  margin-left: -8px;  border-top-color: #222;  border-top-style: solid;  border-top-width: 6px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-bottom {  margin-top: 10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-bottom::before {  border-bottom: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-bottom::after {  border-left: 8px solid transparent;  border-right: 8px solid transparent;  top: -6px;  left: 50%;  margin-left: -8px;  border-bottom-color: #222;  border-bottom-style: solid;  border-bottom-width: 6px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-left {  margin-left: -10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-left::before {  border-left: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-left::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  right: -6px;  top: 50%;  margin-top: -4px;  border-left-color: #222;  border-left-style: solid;  border-left-width: 6px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-right {  margin-left: 10px;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-right::before {  border-right: 8px solid transparent;  }  .t627e968-6bf8-451d-a640-45392c327b40.place-right::after {  border-top: 5px solid transparent;  border-bottom: 5px solid transparent;  left: -6px;  top: 50%;  margin-top: -4px;  border-right-color: #222;  border-right-style: solid;  border-right-width: 6px;  }
# 0                                 % High Meaning:61%
# 1                                 % High Meaning:21%
# 2                                 % High Meaning:54%
# 3                                 % High Meaning:54%
# 4                                 % High Meaning:47%
